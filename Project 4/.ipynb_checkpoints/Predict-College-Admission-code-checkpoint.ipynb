# %%
import pandas as pd

# load data into a pandas dataframe
df = pd.read_csv('Preliminary college year.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    High School GPA  SAT Score    Federal Ethnic Group Gender  \
# 0            2.595      970.0                   White      F
# 1            2.637     1020.0                   White      F
# 2            2.803      930.0  Black/African American      F
# 3            2.354     1080.0         Hispanic/Latino      M
# 4            2.850      880.0                   White      F
#
#    Pell Grant Eligible? (1=yes, 0=no)  Attended Orientation? (1=yes, 0=no)  \
# 0                                 0.0                                  1.0
# 1                                 0.0                                  1.0
# 2                                 1.0                                  1.0
# 3                                 0.0                                  1.0
# 4                                 1.0                                  1.0
#
#    Attended Experience Day? (1=yes, 0=no)  \
# 0                                     0.0
# 1                                     0.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
#
#    Resident/Commuter (1=resident, 0=commuter)  Athlete? (1=yes, 0=no)  \
# 0                                         1.0                     1.0
# 1                                         1.0                     1.0
# 2                                         1.0                     0.0
# 3                                         1.0                     0.0
# 4                                         0.0                     0.0
#
#    Completed Summer Bridge? (2=completed all, 1=completed at least half, 0=did not complete)  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                1.0
# 4                                                2.0
#
#    Dropout Proneness (percentile score before start of semester)  \
# 0                                               55.0
# 1                                                NaN
# 2                                               81.0
# 3                                               88.0
# 4                                               28.0
#
#    Predicted Academic Difficulty (percentile score before start of semester)  \
# 0                                               86.0
# 1                                                NaN
# 2                                               89.0
# 3                                               98.0
# 4                                               72.0
#
#    Educational Stress (percentile score before start of semester)  \
# 0                                               33.0
# 1                                                NaN
# 2                                               95.0
# 3                                               49.0
# 4                                                4.0
#
#    Receptivity to Institutional Help (percentile score before start of semester)  \
# 0                                               53.0
# 1                                                NaN
# 2                                               71.0
# 3                                               52.0
# 4                                               66.0
#
#    Receptivity to Academic Assistance (percentile score before start of semester)  \
# 0                                               25.0
# 1                                                NaN
# 2                                               72.0
# 3                                               76.0
# 4                                               96.0
#
#    Receptivity to Personal Counseling (percentile score before start of semester)  \
# 0                                               30.0
# 1                                                NaN
# 2                                               85.0
# 3                                               30.0
# 4                                               20.0
#
#    Receptivity to Social Engagement (percentile score before start of semester)  \
# 0                                               94.0
# 1                                                NaN
# 2                                               48.0
# 3                                               25.0
# 4                                               85.0
#
#    Receptivity to Career Guidance ((percentile score before start of semester)  \
# 0                                               60.0
# 1                                                NaN
# 2                                               55.0
# 3                                               65.0
# 4                                               50.0
#
#    Receptivity to Financial Guidance (percentile score before start of semester)  \
# 0                                               50.0
# 1                                                NaN
# 2                                               56.0
# 3                                               61.0
# 4                                               50.0
#
#    Desire to Transfer (percentile score before start of semester)  \
# 0                                               82.0
# 1                                                NaN
# 2                                               52.0
# 3                                               96.0
# 4                                               36.0
#
#    Completed Campus Event Requirement? (1=yes, 0=no)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Completed Community Service Requirement? (1=yes, 0=no)  \
# 0                                                1.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Number of Faculty Advisor Meetings Attended  \
# 0                                          5.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          9.0
#
#    Number of Peer Mentor Meetings Attended  Number of Workshops Attended  \
# 0                                      2.0                           2.0
# 1                                      1.0                           2.0
# 2                                      2.0                           3.0
# 3                                      2.0                           0.0
# 4                                      3.0                           3.0
#
#    F17 GPA  S18 GPA  CUM GPA  Number of Credits Earned  \
# 0    0.660     2.20    1.788                      18.0
# 1    1.567     1.66    1.625                      18.0
# 2    2.425     2.25    2.338                      24.0
# 3    0.925      NaN      NaN                       6.0
# 4    3.200     1.68    2.250                      18.0
#
#   Completed Connect? (1=yes, 0=no)      Reason for not Completing Connect  \
# 0                                0  academic dismissal after S18 semester
# 1                                0  academic dismissal after S18 semester
# 2                                1                                    NaN
# 3                                0  academic dismissal after F17 semester
# 4                                1                                    NaN
#
#    Retained F17-F18? (1=yes, 0=no)                    Reason not Retained
# 0                              0.0  academic dismissal after S18 semester
# 1                              0.0  academic dismissal after S18 semester
# 2                              0.0                              financial
# 3                              0.0  academic dismissal after F17 semester
# 4                              1.0                                    NaN

# %%
# create binary indicator variables for categorical features
#df = pd.get_dummies(df, columns=['Gender', 'Federal Ethnic Group'])
df = df.drop(['Gender', 'Federal Ethnic Group'], axis=1)

df.describe()
# Out:
#        High School GPA    SAT Score  Pell Grant Eligible? (1=yes, 0=no)  \
# count       106.000000   102.000000                          106.000000
# mean          2.518443   984.509804                            0.584906
# std           0.267150    85.592026                            0.495079
# min           2.011000   810.000000                            0.000000
# 25%           2.320000   930.000000                            0.000000
# 50%           2.519000   970.000000                            1.000000
# 75%           2.744750  1040.000000                            1.000000
# max           3.163000  1320.000000                            1.000000
#
#        Attended Orientation? (1=yes, 0=no)  \
# count                           106.000000
# mean                              0.981132
# std                               0.136705
# min                               0.000000
# 25%                               1.000000
# 50%                               1.000000
# 75%                               1.000000
# max                               1.000000
#
#        Attended Experience Day? (1=yes, 0=no)  \
# count                              105.000000
# mean                                 0.866667
# std                                  0.341565
# min                                  0.000000
# 25%                                  1.000000
# 50%                                  1.000000
# 75%                                  1.000000
# max                                  1.000000
#
#        Resident/Commuter (1=resident, 0=commuter)  Athlete? (1=yes, 0=no)  \
# count                                  106.000000              106.000000
# mean                                     0.905660                0.235849
# std                                      0.293689                0.426545
# min                                      0.000000                0.000000
# 25%                                      1.000000                0.000000
# 50%                                      1.000000                0.000000
# 75%                                      1.000000                0.000000
# max                                      1.000000                1.000000
#
#        Completed Summer Bridge? (2=completed all, 1=completed at least half, 0=did not complete)  \
# count                                         106.000000
# mean                                            1.707547
# std                                             0.568490
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             2.000000
#
#        Dropout Proneness (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           71.623656
# std                                            22.956440
# min                                            13.000000
# 25%                                            57.000000
# 50%                                            80.000000
# 75%                                            91.000000
# max                                            99.000000
#
#        Predicted Academic Difficulty (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           72.268817
# std                                            21.885641
# min                                            17.000000
# 25%                                            59.000000
# 50%                                            77.000000
# 75%                                            91.000000
# max                                            99.000000
#
#        Educational Stress (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           61.365591
# std                                            30.063623
# min                                             3.000000
# 25%                                            33.000000
# 50%                                            75.000000
# 75%                                            87.000000
# max                                            99.000000
#
#        Receptivity to Institutional Help (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           57.720430
# std                                            29.117216
# min                                             1.000000
# 25%                                            34.000000
# 50%                                            65.000000
# 75%                                            81.000000
# max                                            99.000000
#
#        Receptivity to Academic Assistance (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           54.494624
# std                                            30.712065
# min                                             1.000000
# 25%                                            25.000000
# 50%                                            55.000000
# 75%                                            83.000000
# max                                            99.000000
#
#        Receptivity to Personal Counseling (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           59.967742
# std                                            26.055731
# min                                            20.000000
# 25%                                            30.000000
# 50%                                            67.000000
# 75%                                            83.000000
# max                                            99.000000
#
#        Receptivity to Social Engagement (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           51.419355
# std                                            30.374232
# min                                             1.000000
# 25%                                            25.000000
# 50%                                            48.000000
# 75%                                            80.000000
# max                                            99.000000
#
#        Receptivity to Career Guidance ((percentile score before start of semester)  \
# count                                          93.000000
# mean                                           55.967742
# std                                            30.805297
# min                                             1.000000
# 25%                                            27.000000
# 50%                                            55.000000
# 75%                                            84.000000
# max                                            99.000000
#
#        Receptivity to Financial Guidance (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           57.322581
# std                                            29.324704
# min                                             3.000000
# 25%                                            34.000000
# 50%                                            61.000000
# 75%                                            79.000000
# max                                            99.000000
#
#        Desire to Transfer (percentile score before start of semester)  \
# count                                          93.000000
# mean                                           63.333333
# std                                            21.410244
# min                                            36.000000
# 25%                                            36.000000
# 50%                                            63.000000
# 75%                                            82.000000
# max                                            99.000000
#
#        Completed Campus Event Requirement? (1=yes, 0=no)  \
# count                                         106.000000
# mean                                            0.698113
# std                                             0.461257
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Completed Community Service Requirement? (1=yes, 0=no)  \
# count                                         106.000000
# mean                                            0.820755
# std                                             0.385380
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Number of Faculty Advisor Meetings Attended  \
# count                                   107.000000
# mean                                      5.196262
# std                                      26.671460
# min                                       0.000000
# 25%                                       2.000000
# 50%                                       2.000000
# 75%                                       3.000000
# max                                     278.000000
#
#        Number of Peer Mentor Meetings Attended  Number of Workshops Attended  \
# count                               106.000000                    106.000000
# mean                                  2.764151                      3.075472
# std                                   1.489979                      6.511087
# min                                   0.000000                      0.000000
# 25%                                   2.000000                      1.000000
# 50%                                   3.000000                      3.000000
# 75%                                   3.750000                      3.000000
# max                                   8.000000                     68.000000
#
#           F17 GPA    S18 GPA    CUM GPA  Number of Credits Earned  \
# count  104.000000  87.000000  87.000000                106.000000
# mean     2.466644   2.436897   2.572368                 21.481132
# std      1.009796   0.907564   0.679156                  9.006063
# min      0.000000   0.000000   0.750000                  0.000000
# 25%      2.000000   1.812500   2.170000                 18.000000
# 50%      2.775000   2.575000   2.644000                 24.000000
# 75%      3.167250   3.100000   3.001500                 27.000000
# max      3.900000   4.000000   3.930000                 33.000000
#
#        Retained F17-F18? (1=yes, 0=no)
# count                       106.000000
# mean                          0.622642
# std                           0.487029
# min                           0.000000
# 25%                           0.000000
# 50%                           1.000000
# 75%                           1.000000
# max                           1.000000

# %% [markdown]
# ### Fill NaN values with median

# %%
df.fillna(df.median(numeric_only=True).round(1), inplace=True)
df.head()
# Out:
#    High School GPA  SAT Score  Pell Grant Eligible? (1=yes, 0=no)  \
# 0            2.595      970.0                                 0.0
# 1            2.637     1020.0                                 0.0
# 2            2.803      930.0                                 1.0
# 3            2.354     1080.0                                 0.0
# 4            2.850      880.0                                 1.0
#
#    Attended Orientation? (1=yes, 0=no)  \
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
#    Attended Experience Day? (1=yes, 0=no)  \
# 0                                     0.0
# 1                                     0.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
#
#    Resident/Commuter (1=resident, 0=commuter)  Athlete? (1=yes, 0=no)  \
# 0                                         1.0                     1.0
# 1                                         1.0                     1.0
# 2                                         1.0                     0.0
# 3                                         1.0                     0.0
# 4                                         0.0                     0.0
#
#    Completed Summer Bridge? (2=completed all, 1=completed at least half, 0=did not complete)  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                1.0
# 4                                                2.0
#
#    Dropout Proneness (percentile score before start of semester)  \
# 0                                               55.0
# 1                                               80.0
# 2                                               81.0
# 3                                               88.0
# 4                                               28.0
#
#    Predicted Academic Difficulty (percentile score before start of semester)  \
# 0                                               86.0
# 1                                               77.0
# 2                                               89.0
# 3                                               98.0
# 4                                               72.0
#
#    Educational Stress (percentile score before start of semester)  \
# 0                                               33.0
# 1                                               75.0
# 2                                               95.0
# 3                                               49.0
# 4                                                4.0
#
#    Receptivity to Institutional Help (percentile score before start of semester)  \
# 0                                               53.0
# 1                                               65.0
# 2                                               71.0
# 3                                               52.0
# 4                                               66.0
#
#    Receptivity to Academic Assistance (percentile score before start of semester)  \
# 0                                               25.0
# 1                                               55.0
# 2                                               72.0
# 3                                               76.0
# 4                                               96.0
#
#    Receptivity to Personal Counseling (percentile score before start of semester)  \
# 0                                               30.0
# 1                                               67.0
# 2                                               85.0
# 3                                               30.0
# 4                                               20.0
#
#    Receptivity to Social Engagement (percentile score before start of semester)  \
# 0                                               94.0
# 1                                               48.0
# 2                                               48.0
# 3                                               25.0
# 4                                               85.0
#
#    Receptivity to Career Guidance ((percentile score before start of semester)  \
# 0                                               60.0
# 1                                               55.0
# 2                                               55.0
# 3                                               65.0
# 4                                               50.0
#
#    Receptivity to Financial Guidance (percentile score before start of semester)  \
# 0                                               50.0
# 1                                               61.0
# 2                                               56.0
# 3                                               61.0
# 4                                               50.0
#
#    Desire to Transfer (percentile score before start of semester)  \
# 0                                               82.0
# 1                                               63.0
# 2                                               52.0
# 3                                               96.0
# 4                                               36.0
#
#    Completed Campus Event Requirement? (1=yes, 0=no)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Completed Community Service Requirement? (1=yes, 0=no)  \
# 0                                                1.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Number of Faculty Advisor Meetings Attended  \
# 0                                          5.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          9.0
#
#    Number of Peer Mentor Meetings Attended  Number of Workshops Attended  \
# 0                                      2.0                           2.0
# 1                                      1.0                           2.0
# 2                                      2.0                           3.0
# 3                                      2.0                           0.0
# 4                                      3.0                           3.0
#
#    F17 GPA  S18 GPA  CUM GPA  Number of Credits Earned  \
# 0    0.660     2.20    1.788                      18.0
# 1    1.567     1.66    1.625                      18.0
# 2    2.425     2.25    2.338                      24.0
# 3    0.925     2.60    2.600                       6.0
# 4    3.200     1.68    2.250                      18.0
#
#   Completed Connect? (1=yes, 0=no)      Reason for not Completing Connect  \
# 0                                0  academic dismissal after S18 semester
# 1                                0  academic dismissal after S18 semester
# 2                                1                                    NaN
# 3                                0  academic dismissal after F17 semester
# 4                                1                                    NaN
#
#    Retained F17-F18? (1=yes, 0=no)                    Reason not Retained
# 0                              0.0  academic dismissal after S18 semester
# 1                              0.0  academic dismissal after S18 semester
# 2                              0.0                              financial
# 3                              0.0  academic dismissal after F17 semester
# 4                              1.0                                    NaN

# %% [markdown]
# ### Drop the 'Reason for not Completing Connect' and 'Reason not Retained' are different for different person, so drop it for some time so that we can evaluate

# %%
df = df.drop('Reason for not Completing Connect', axis=1)
df = df.drop('Reason not Retained', axis=1)

# %%
df.head()
# Out:
#    High School GPA  SAT Score  Pell Grant Eligible? (1=yes, 0=no)  \
# 0            2.595      970.0                                 0.0
# 1            2.637     1020.0                                 0.0
# 2            2.803      930.0                                 1.0
# 3            2.354     1080.0                                 0.0
# 4            2.850      880.0                                 1.0
#
#    Attended Orientation? (1=yes, 0=no)  \
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
#
#    Attended Experience Day? (1=yes, 0=no)  \
# 0                                     0.0
# 1                                     0.0
# 2                                     1.0
# 3                                     1.0
# 4                                     1.0
#
#    Resident/Commuter (1=resident, 0=commuter)  Athlete? (1=yes, 0=no)  \
# 0                                         1.0                     1.0
# 1                                         1.0                     1.0
# 2                                         1.0                     0.0
# 3                                         1.0                     0.0
# 4                                         0.0                     0.0
#
#    Completed Summer Bridge? (2=completed all, 1=completed at least half, 0=did not complete)  \
# 0                                                2.0
# 1                                                2.0
# 2                                                1.0
# 3                                                1.0
# 4                                                2.0
#
#    Dropout Proneness (percentile score before start of semester)  \
# 0                                               55.0
# 1                                               80.0
# 2                                               81.0
# 3                                               88.0
# 4                                               28.0
#
#    Predicted Academic Difficulty (percentile score before start of semester)  \
# 0                                               86.0
# 1                                               77.0
# 2                                               89.0
# 3                                               98.0
# 4                                               72.0
#
#    Educational Stress (percentile score before start of semester)  \
# 0                                               33.0
# 1                                               75.0
# 2                                               95.0
# 3                                               49.0
# 4                                                4.0
#
#    Receptivity to Institutional Help (percentile score before start of semester)  \
# 0                                               53.0
# 1                                               65.0
# 2                                               71.0
# 3                                               52.0
# 4                                               66.0
#
#    Receptivity to Academic Assistance (percentile score before start of semester)  \
# 0                                               25.0
# 1                                               55.0
# 2                                               72.0
# 3                                               76.0
# 4                                               96.0
#
#    Receptivity to Personal Counseling (percentile score before start of semester)  \
# 0                                               30.0
# 1                                               67.0
# 2                                               85.0
# 3                                               30.0
# 4                                               20.0
#
#    Receptivity to Social Engagement (percentile score before start of semester)  \
# 0                                               94.0
# 1                                               48.0
# 2                                               48.0
# 3                                               25.0
# 4                                               85.0
#
#    Receptivity to Career Guidance ((percentile score before start of semester)  \
# 0                                               60.0
# 1                                               55.0
# 2                                               55.0
# 3                                               65.0
# 4                                               50.0
#
#    Receptivity to Financial Guidance (percentile score before start of semester)  \
# 0                                               50.0
# 1                                               61.0
# 2                                               56.0
# 3                                               61.0
# 4                                               50.0
#
#    Desire to Transfer (percentile score before start of semester)  \
# 0                                               82.0
# 1                                               63.0
# 2                                               52.0
# 3                                               96.0
# 4                                               36.0
#
#    Completed Campus Event Requirement? (1=yes, 0=no)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Completed Community Service Requirement? (1=yes, 0=no)  \
# 0                                                1.0
# 1                                                0.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    Number of Faculty Advisor Meetings Attended  \
# 0                                          5.0
# 1                                          3.0
# 2                                          2.0
# 3                                          2.0
# 4                                          9.0
#
#    Number of Peer Mentor Meetings Attended  Number of Workshops Attended  \
# 0                                      2.0                           2.0
# 1                                      1.0                           2.0
# 2                                      2.0                           3.0
# 3                                      2.0                           0.0
# 4                                      3.0                           3.0
#
#    F17 GPA  S18 GPA  CUM GPA  Number of Credits Earned  \
# 0    0.660     2.20    1.788                      18.0
# 1    1.567     1.66    1.625                      18.0
# 2    2.425     2.25    2.338                      24.0
# 3    0.925     2.60    2.600                       6.0
# 4    3.200     1.68    2.250                      18.0
#
#   Completed Connect? (1=yes, 0=no)  Retained F17-F18? (1=yes, 0=no)
# 0                                0                              0.0
# 1                                0                              0.0
# 2                                1                              0.0
# 3                                0                              0.0
# 4                                1                              1.0

# %% [markdown]
# ### Split the data into training and testing sets to evaluate the performance of the logistic model.

# %%
from sklearn.model_selection import train_test_split

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('Retained F17-F18', axis=1), df['Retained F17-F18'].astype(int), test_size=0.2, random_state=102)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_60/1409044362.py in <module>
#       2
#       3 # split data into training and testing sets
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(df.drop('Retained F17-F18', axis=1), df['Retained F17-F18'].astype(int), test_size=0.2, random_state=102)
#
# ~/.local/lib/python3.10/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5566                 weight  1.0     0.8
#    5567         """
# -> 5568         return super().drop(
#    5569             labels=labels,
#    5570             axis=axis,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4780         for axis, labels in axes.items():
#    4781             if labels is not None:
# -> 4782                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4783
#    4784         if inplace:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4822                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4823             else:
# -> 4824                 new_axis = axis.drop(labels, errors=errors)
#    4825             indexer = axis.get_indexer(new_axis)
#    4826
#
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7067         if mask.any():
#    7068             if errors != "ignore":
# -> 7069                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7070             indexer = indexer[~mask]
#    7071         return self.delete(indexer)
#
# KeyError: "['Retained F17-F18'] not found in axis"

# %% [markdown]
# ### Fit a logistic regression model to the training data, using a subset of the variables that are most likely to be significant predictors of the outcome based on domain knowledge or exploratory analysis.

# %%
# df.head()
# from sklearn.linear_model import LogisticRegression
# X = df.iloc[:,0:28]

# df['Retained F17-F18'] = df['Retained F17-F18'].astype(int)
# y = df['Retained F17-F18']

# # fit a logistic regression model
# model = LogisticRegression(max_iter=8000,solver='sag')
# model.fit(X,y)


from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('Retained F17-F18? (1=yes, 0=no)', axis=1), df['Retained F17-F18? (1=yes, 0=no)'].astype(int), test_size=0.2, random_state=102)

# Initialize and fit a logistic regression model on the training data
model = LogisticRegression(max_iter=8000, solver='sag')
model.fit(X_train, y_train)

# Evaluate the model on the testing data
accuracy = model.score(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60/3938526465.py in <module>
#      18 # Initialize and fit a logistic regression model on the training data
#      19 model = LogisticRegression(max_iter=8000, solver='sag')
# ---> 20 model.fit(X_train, y_train)
#      21
#      22 # Evaluate the model on the testing data
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1206             _dtype = [np.float64, np.float32]
#    1207
# -> 1208         X, y = self._validate_data(
#    1209             X,
#    1210             y,
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620                 y = check_array(y, input_name="y", **check_y_params)
#     621             else:
# --> 622                 X, y = check_X_y(X, y, **check_params)
#     623             out = X, y
#     624
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1144         )
#    1145
# -> 1146     X = check_array(
#    1147         X,
#    1148         accept_sparse=accept_sparse,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    2148     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2149         values = self._values
# -> 2150         arr = np.asarray(values, dtype=dtype)
#    2151         if (
#    2152             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: '0, contract for fall'

# %% [markdown]
# ### Evaluate the performance of the model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1 score: {f1:.3f}')
# Out:
# Accuracy: 0.955
# Precision: 1.000
# Recall: 0.938
# F1 score: 0.968

# %% [markdown]
# ### Coefficient values: In logistic regression, the coefficients represent the amount of change in the log odds of the outcome variable for a unit change in the predictor variable. Larger absolute values of the coefficients indicate greater importance of the corresponding predictor variable.

# %%
# Identify important features
coefficients = pd.DataFrame({"feature": X.columns, "coefficient": model.coef_[0]})
coefficients = coefficients.sort_values(by="coefficient", ascending=False)
print("Important features:\n", coefficients)
# Out:
# Important features:
#                                          feature  coefficient
# 26                     Number of Credits Earned     0.245281
# 21      Number of Peer Mentor Meetings Attended     0.115682
# 22                 Number of Workshops Attended     0.107437
# 27                            Completed Connect     0.044147
# 23                                      F17 GPA     0.043918
# 25                                      CUM GPA     0.018003
# 14             Receptivity to Social Engagement     0.017549
# 19      Completed Community Service Requirement     0.017396
# 8                             Dropout Proneness     0.016758
# 18           Completed Campus Event Requirement     0.012978
# 12           Receptivity to Academic Assistance     0.012295
# 7                       Completed Summer Bridge     0.011217
# 3                          Attended Orientation     0.010218
# 20  Number of Faculty Advisor Meetings Attended     0.007198
# 4                       Attended Experience Day     0.006801
# 13           Receptivity to Personal Counseling     0.005812
# 24                                      S18 GPA     0.004886
# 10                           Educational Stress     0.003479
# 15               Receptivity to Career Guidance     0.001127
# 6                                       Athlete     0.000719
# 2                           Pell Grant Eligible    -0.002030
# 1                                     SAT Score    -0.003570
# 5                             Resident/Commuter    -0.010209
# 0                               High School GPA    -0.012929
# 17                           Desire to Transfer    -0.014957
# 16            Receptivity to Financial Guidance    -0.018620
# 11            Receptivity to Institutional Help    -0.022974
# 9                 Predicted Academic Difficulty    -0.028276
